# %% [markdown]
# # Assignment w3-4
# # Lec1: Tuto1, datasets, data loading and utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/'
# Out:
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials

# %%
import os
data_path1 = '/content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/'
if not os.path.isdir(data_path1+"/data_temp5/"):
  os.mkdir(data_path1+'/data_temp5/')

# %% [markdown]
# ## Datasets in Torchvision

# %% [markdown]
# #### Download and Save MNIST

# %%
import torchvision
data_train = torchvision.datasets.MNIST('data_temp5/mnist_data1', train = True, download = True)

# %%
# Hoac dung
from torchvision.datasets import MNIST
data_train = MNIST(root = 'data_temp5/mnist_data2',train = True,download = True)

# %%
from torchvision.datasets import MNIST
# from torchvision import datasets, transforms
from torchvision import transforms
data_train = MNIST('~/mnist_data', train = True, download = True, transform = transforms.ToTensor()) # chuyen sang tensor
# Out:
# ...
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting /root/mnist_data/MNIST/raw/train-images-idx3-ubyte.gz to /root/mnist_data/MNIST/raw
#
# ...
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting /root/mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz to /root/mnist_data/MNIST/raw
#
# ...
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting /root/mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz to /root/mnist_data/MNIST/raw
#
# ...
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting /root/mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /root/mnist_data/MNIST/raw

# %%
import torch

train_data = torch.Tensor(60000, 28, 28)
train_label = torch.LongTensor(60000)
for idx, ex in enumerate(data_train):
  train_data[idx] = ex[0]
  train_label[idx] = ex[1]

# %%
print(os.getcwd())
# Out:
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials

# %%
torch.save(train_data, os.getcwd()+'/mnist_train_data.pt')
torch.save(train_label, os.getcwd()+'/mnist_train_label.pt')

# %% [markdown]
# #### Looking at the MNIST Dataset in-Depth
# First let's download the datasets and load it in a variable named data_train.\
# Then we'll print a sample image

# %%
import matplotlib.pyplot as plt
data_train = MNIST('data_temp5/mnist_data2', train = True, download = True)
random_image = data_train[1][0] # data_train[0]: image; data_train[1]: label
random_image_label = data_train[1][1]

# Print the Image using mpl
plt.imshow(random_image, cmap = 'jet')
plt.title('image label is: {}'.format(str(random_image_label)));

# %%
### Again!!!!
random_image, label = data_train[6]

plt.imshow(random_image, cmap = 'viridis')
plt.title('image label is: {}'.format(label));

# %%
### Again two more time!
random, label = data_train[21]

plt.imshow(random, cmap = 'RdGy')
plt.title('label: %s' %(label))
# Out:
# Text(0.5, 1.0, 'label: 0')

# %%
import numpy as np
print(np.array(data_train).shape)
# Out:
# <ipython-input-13-9fb4d9add047>:2: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   print(np.array(data_train).shape)
# (60000, 2)
# <ipython-input-13-9fb4d9add047>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   print(np.array(data_train).shape)

# %% [markdown]
# I've already use data_train elements like a tuple! It's very convenient! Let's try to do something bigger!!!!

# %%
fig = plt.figure(figsize = (20,5))
for idx in range(0,12):
  im, label = data_train[idx]
  ax = fig.add_subplot(1,12,idx+1)
  ax.imshow(im, cmap = 'viridis')
  ax.axis('off')
  ax.set_title(label)

# %%
random_ = np.random.randint(0,100,12).tolist()
print(random_)
fig = plt.figure(figsize=(20,5))
for idx in range(len(random_)):
  im, label = data_train[random_[idx]]
  ax = fig.add_subplot(1,12,idx+1)
  ax.imshow(im, cmap = 'gray')
  ax.axis('off')
  ax.set_title(label)
# Out:
# [54, 86, 42, 86, 49, 1, 36, 31, 95, 20, 29, 69]

# %% [markdown]
# ## Thực hành với CIFAR10

# %%
from torchvision.datasets import CIFAR10
data_train2 = CIFAR10('/data_temp5/cifar10_data2', train = True, download = True)
# Out:
# ...
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /data_temp5/cifar10_data2/cifar-10-python.tar.gz to /data_temp5/cifar10_data2

# %%
random_image, label = data_train2[21]
plt.imshow(random_image)
plt.title(label);

# %%
random_ = np.random.randint(0,100,12).tolist()
print(random_)
fig = plt.figure(figsize=(20,5))
for idx in range(len(random_)):
  im, label = data_train2[random_[idx]]
  ax = fig.add_subplot(1,12,idx+1)
  ax.imshow(im, cmap = 'gray')
  ax.axis('off')
  ax.set_title(label)
# Out:
# [75, 11, 3, 74, 85, 53, 14, 44, 42, 85, 12, 6]

# %%
print('number of classes' ,np.max(np.array(data_train2)[1][1])+1) # +1 for the number zero.
# Out:
# <ipython-input-19-fdf9948cb325>:1: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   print('number of classes' ,np.max(np.array(data_train2)[1][1])+1) # +1 for the number zero.
# <ipython-input-19-fdf9948cb325>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   print('number of classes' ,np.max(np.array(data_train2)[1][1])+1) # +1 for the number zero.
# ...

# %% [markdown]
# 0 -> 9, respectively, airplan, automobile, bird, cat, deer, dog, frog, horse, ship, truck.

# %% [markdown]
# ## ImageFolder Class
# Load our own datasets!!!!!

# %% [markdown]
# Đầu tiên chuẩn bị dữ liệu gồm 2 lớp

# %%
print(os.getcwd())
# Out:
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials

# %%
data_tuto1_root = os.getcwd() + '/Data_tuto1'

# %%
import pathlib

root = pathlib.Path(data_tuto1_root)
print(root)
for p in root.iterdir():
  print(p)
# Out:
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/apple
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/orange

# %%
data = pathlib.Path(data_tuto1_root+'/apple')
for p in data.iterdir():
  print(p)
# Out:
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/apple/apple_4.jpg
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/apple/apple_1.jpg
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/apple/apple_3.jpg
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/apple/apple_2.jpg
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/apple/apple_5.jpg

# %%
data = pathlib.Path(data_tuto1_root+'/orange')
for p in data.iterdir():
  print(p)
# Out:
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/orange/orange_3.jpg
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/orange/orange_5.jpg
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/orange/orange_1.jpg
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/orange/orange_2.jpg
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/Data_tuto1/orange/orange_4.jpg

# %% [markdown]
# Đọc dữ liệu đã chuẩn bị với dạng thức: torchvision.datasets

# %%
data_train = torchvision.datasets.ImageFolder(data_tuto1_root)

# %%
random_image, label = data_train[0]
plt.imshow(random_image)
plt.title(label);

# %%
random_image, label = data_train[1]
plt.imshow(random_image)
plt.title(label);

# %%
fig = plt.figure(figsize = (20,5))
for i in range(10):
  im, label = data_train[i]
  ax = fig.add_subplot(1,10,i+1)
  ax.axis('off')
  ax.set_title(label)
  ax.imshow(im)

# %% [markdown]
# ## Data Loading in Pytorch

# %%
from torch.utils.data import DataLoader

# %% [markdown]
# Let's now discuss in detail the parameters that the DataLoader class accepts, shown below.

# %%
# Import MNIST
from torchvision.datasets import MNIST
dataset = MNIST

# %%
from torch.utils.data import DataLoader
DataLoader(
    dataset,
    batch_size = 1,
    shuffle = False,
    num_workers = 0,
    collate_fn = None,
    pin_memory = False,
)

# %% [markdown]
# ## Looking at the MNIST Dataset in-Depth

# %%
# Import MNIST
from torchvision.datasets import MNIST

# Download and Save MNIST
data_train = MNIST('~/mnist_data', train = True, download = True)

# Print Data
print(data_train)
# print(data_train[12])
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: /root/mnist_data
#     Split: Train

# %%
random_ = np.random.randint(0,100,12).tolist()
print(random_)
fig = plt.figure(figsize=(20,5))
for idx in range(len(random_)):
  im, label = data_train[random_[idx]]
  ax = fig.add_subplot(1,12,idx+1)
  ax.imshow(im, cmap = 'gray')
  ax.axis('off')
  ax.set_title(label)
# Out:
# [21, 84, 20, 96, 87, 68, 88, 3, 46, 21, 98, 90]

# %% [markdown]
# ## Chuẩn bị dữ liệu cho huấn luyện mô hình

# %% [markdown]
# Có thể gộp Dataset vào DataLoader

# %%
import torch
from torchvision import transforms

data_train_batch_1 = torch.utils.data.DataLoader(
    MNIST(
        '~/mnist_data', train=True, download = True, transform = transforms.Compose([transforms.ToTensor()])),
        batch_size = 64,
        shuffle = True
        )

# for batch_idx, samples in enumberate(data_train):
#       print(batch_idx, samples)

# %%
print(len(data_train_batch_1))
# Out:
# 938

# %% [markdown]
# hoac tach rieng

# %%
data_train = MNIST('~/mnist_data', train = True, download = True, transform = transforms.Compose([transforms.ToTensor()]))
data_train_batch_2 = torch.utils.data.DataLoader(data_train, batch_size = 200, shuffle = True)

# %%
print(len(data_train))
print(len(data_train_batch_2))
# Out:
# 60000
# 300

# %%
data_train_batch_2 = torch.utils.data.DataLoader(data_train, batch_size = 64, shuffle = False )

# %%
print(len(data_train))
print(len(data_train_batch_2))
# Out:
# 60000
# 938

# %%
from torch.autograd import Variable
# from torchvision import transforms
for i, (images, labels) in enumerate(data_train_batch_2):
  images = Variable(images)
  labels = Variable(labels)

# %%
plt.rcParams['figure.figsize'] = [20, 5]
for idx in range(1,10):
  plt.subplot(1,10,idx).imshow(images[idx].squeeze(),cmap='gray'),plt.xticks([]),plt.yticks([]),plt.title(labels[idx].numpy())
