# %% [markdown]
# # Lec1: Tuto1-Lab02: custom dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/'
# Out:
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials

# %% [markdown]
# So far, we've learned to load datasets along with various ways to preprocess the data. In this section, we'll create a simple custom dataset consisting of numbers and text. We'll talk about the Dataset object in PyTorch that helps to handle numerical and text files, and how one could go about optimizing the pipeline (quy trinh) for a certain task. The trick here is to abstract the **getitem()**

# %% [markdown]
# The **getitem()** method returns the selected sample in the datase by indexing.\
# And the **len()** is not much different like in string class!

# %%
class Dataset(object):
  def __getitem__(self, index):
    raise NotImplementedError

  def __len__(self):
    raise NotImplementedError

# %% [markdown]
# Creating a custom dataset isn't complex, but as an additional step to the typical procedure of loading data, it is necessary to build an interface in order to get a nice abstraction (a nice syntactic sugar to say the least). Now we'll create a new dataset that has numbers and their squared values. Let's call our dataset SquareDataset. Its purpose is to return squares of values in the range [a,b]

# %%
import torch

class SquareDataset(Dataset):
  def __init__(self, a = 0, b = 1):
    super(Dataset, self).__init__() # inherits from the super-class
    # can also use like super().__init__(attributes)
    assert a <= b
    self.a = a
    self.b = b

  # Make a unique __len__ method for the subclass
  def __len__(self):
    return self.b - self.a + 1
  # Another unique method for the subclass
  def __getitem__(self, index):
      assert self.a <= index <= self.b
      return index, index**2

# %%
test_1 = SquareDataset(a=1, b=64)
print(len(test_1))
print(test_1[4])
# Out:
# 64
# (4, 16)

# %%
from torch.utils.data import DataLoader
data_train = SquareDataset(a = 1, b = 64)
data_train_loader = DataLoader(data_train, batch_size = 32, shuffle = True)
print(data_train_loader)
print(len(data_train_loader))
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f17d4428c40>
# 2

# %%
data_train = SquareDataset(a = 1, b = 64)
data_train_loader = DataLoader(data_train, batch_size = 4, shuffle = True)
print(len(data_train_loader))
# Out:
# 16

# %% [markdown]
# In the above code block, we created a Python class named **SquareDataset** that inherits the Dataset class from Pytorch. Next, we called an **init()** constructor where a and b were initialized to 0 and 1, respectively. The super class is used to access the len and get_item methoads from the inherited Dataset class. Next we used the assert statement to check if a is less than or equal to b, as we want to create a dataset wherein the values would lie between a and b.

# %% [markdown]
# We then created a dataset using the SquareDataset class, where the data values lie in the range 1 to 64. We loaded this into a variable named data_train. Lastly, the **DataLoader** class created an iterator over the data stored in data_train_loader with a batch_size initialized to 64, and shuffle set to True\
#
# DataLoader chia tập dữ liệu thành các batch, như ví dụ trên, nó chia tập dữ liệu thành 2 phần mỗi phần có kích thước 32, có xáo trộn các phần tử.

# %% [markdown]
# Data loaders exploit the goodness of Python by employing pieces of OOP concepts. A good excercise would be to go through a variety of data loaders with a number of popular datasets including CelebA, PIMA, COCO, ImageNet, CIFAR-10/100, etc.

# %% [markdown]
# torch.utils.data.Dataset: for images

# %% [markdown]
# for image segmentation task: image pair {image, label}\
# segmentation: label: map, mask, target

# %%
import torch
import imageio

"""
similar to:
from torch.utils.data import Dataset
class ImageDataset_segment(Dataset):
"""
class ImageDataset_segment(torch.utils.data.Dataset):
  def __init__(self, root, N, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.input, self.target = [], []
    for i in range(N):
      t = imageio.imread(f'{root}/input/ISIC_00{24306+i}.jpg') # (w,h,3) # PIL.image, opencv
      t = torch.from_numpy(t).permute(2, 0, 1) # from numpy to tensor (3, w, h)
      # l = imageio.imread(f'target{i}.png)
      l = imageio.imread(f'{root}/target/ISIC_00{24306+i}_segmentation.png') # PIL.Image, opencv.imread...
      # l = torch.from_numpy(l).permute(2, 0, 1)
      self.input.append(t)
      self.target.append(l)
  def __getitem__(self, idx):
    return {'input':self.input[idx], 'target':self.target[idx]} # data pairs
  def __len__(self):
    return len(self.input)

    # input, target = ImageDataset_segment(root, N);

# %%
import torch
import os
dataPath = os.getcwd() + '/HAM10000'
print(dataPath)
# Out:
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/HAM10000

# %%
myImageDataset = ImageDataset_segment(dataPath, 5)
# # iterating thruogh the samples
# for sample in myImageDataset
#     input = sample['input'].cpu() # or .cuda()
#     target = sample['target].cpu() # or .to(device)

# %%
import matplotlib.pyplot as plt
for i, ex in enumerate(myImageDataset):
  img = ex['input']
  mask = ex['target']
  # %matplotlib inline
  plt.rcParams['figure.figsize'] = [10, 8]
  plt.figure(i)
  plt.clf
  plt.subplot(1,3,1).imshow(img.permute(1,2,0)),plt.title('image')
  plt.subplot(1,3,2).imshow(mask, cmap = 'gray'),plt.title('label')
  plt.subplot(1,3,3).imshow(img.permute(1,2,0)),plt.title('image with label contour')
  plt.contour(mask,1,colors='g',linewidth=1.5);
  # plt.show(block=False),plt.pause(0.01);
# Out:
# <ipython-input-11-c57680acaecd>:12: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(mask,1,colors='g',linewidth=1.5);

# %%
# # iterating through the samples
for sample in myImageDataset:
  input = sample['input'].cpu() # or .cuda()
  target = torch.tensor(sample['target']).cpu() # or .to(device)

# %%
len(input)
# Out:
# 3

# %%
img0 = input[2]
label0 = target

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 8]
plt.subplot(121)
plt.imshow(img0), plt.title('image')
plt.subplot(122)
plt.imshow(label0, cmap = 'gray'), plt.title('label');

# %%
print(img0.size())
print(label0.size())
# Out:
# torch.Size([450, 600])
# torch.Size([450, 600])

# %%
data_path = os.getcwd()
img_data = torch.Tensor(5, 3, 450, 600)
label_data = torch.Tensor(5,3,450, 600)

for idx, ex in enumerate(myImageDataset):
  img_data[idx] = ex['input']
  label_data[idx] = torch.tensor(ex['target'])

torch.save(img_data, data_path + '/sample_skin_data.pt')
torch.save(label_data, data_path + '/sample_skin_label.pt')
# Out:
# <ipython-input-48-977aa44b1cad>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   label_data[idx] = torch.tensor(ex['target'])

# %% [markdown]
# ## Thử lại với PIL

# %%
import torch
import imageio
from PIL import Image
import numpy as np

"""
similar to:
from torch.utils.data import Dataset
class ImageDataset_segment(Dataset):
"""
class ImageDataset_segment(torch.utils.data.Dataset):
  def __init__(self, root, N, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.input, self.target = [], []
    for i in range(N):
      t = np.array(Image.open(f'{root}/input/ISIC_00{24306+i}.jpg'))
      t = torch.from_numpy(t).permute(2, 0, 1)
      # l = imageio.imread(f'target{i}.png)
      l = np.array(Image.open(f'{root}/target/ISIC_00{24306+i}_segmentation.png'))
      l = torch.from_numpy(l)
      # l = torch.from_numpy(l).permute(2, 0, 1)
      self.input.append(t)
      self.target.append(l)
  def __getitem__(self, idx):
    return {'input':self.input[idx], 'target':self.target[idx]} # data pairs
  def __len__(self):
    return len(self.input)

    # input, target = ImageDataset_segment(root, N);

# %%
import torch
import os
dataPath = os.getcwd() + '/HAM10000'
print(dataPath)
# Out:
# /content/drive/MyDrive/HUST GIFTED CLASS K66/IPSAL LAB/Computer vision/Slides/Tuan3_4/assignment/Tutorials/HAM10000

# %%
myImageDataset = ImageDataset_segment(dataPath, 5)
# # iterating thruogh the samples
# for sample in myImageDataset
#     input = sample['input'].cpu() # or .cuda()
#     target = sample['target].cpu() # or .to(device)

# %%
import matplotlib.pyplot as plt
for i, ex in enumerate(myImageDataset):
  img = ex['input']
  mask = ex['target']
  # %matplotlib inline
  plt.rcParams['figure.figsize'] = [10, 8]
  plt.figure(i)
  plt.clf
  plt.subplot(1,3,1).imshow(img.permute(1,2,0)),plt.title('image')
  plt.subplot(1,3,2).imshow(mask, cmap = 'gray'),plt.title('label')
  plt.subplot(1,3,3).imshow(img.permute(1,2,0)),plt.title('image with label contour')
  plt.contour(mask,1,colors='g',linewidth=1.5);
  # plt.show(block=False),plt.pause(0.01);
# Out:
# <ipython-input-21-c57680acaecd>:12: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(mask,1,colors='g',linewidth=1.5);

# %%
# # iterating through the samples
for sample in myImageDataset:
  input = sample['input'].cpu() # or .cuda()
  target = sample['target'].cpu() # or .to(device)

# %%
img0 = input[2]
label0 = target

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 8]
plt.subplot(121)
plt.imshow(img0), plt.title('image')
plt.subplot(122)
plt.imshow(label0, cmap = 'gray'), plt.title('label');

# %%
print(img0.size())
print(label0.size())
# Out:
# torch.Size([450, 600])
# torch.Size([450, 600])

# %%
data_path = os.getcwd()
img_data = np.zeros((5, 450, 600, 3))
label_data = np.zeros((5, 450, 600))

for idx, ex in enumerate(myImageDataset):
  img_data[idx] = ex['input'].permute(1,2,0).numpy()
  label_data[idx] = ex['target'].numpy()

np.save(data_path + '/sample_skin_data.npy', img_data)
np.save(data_path + '/sample_skin_label.npy', label_data)

# %% [markdown]
# Có thể dùng cấu trúc trên để load lại các dữ liệu trước đó đã được lưu dưới dạng npy hay matlab

# %% [markdown]
# ## torch.utils.data.Dataset: imaegs for classifiaction task

# %% [markdown]
# read images from a folder, image classes are embedded in files names; Preprocessing operations are defined inside the dataset

# %%
import numpy as np
from PIL import Image
import glob
from torch.utils.data.dataset import Dataset

# %%
class CustomDatasetFromFile(Dataset):
  def __init__(self, folder_path):
    """
    A dataset exmaple where the class is embedded in the file names
    This data example also does not use any torch transforms
    Args:
        folder_path (string): path to image folder
    """
    # Get image list
    self.image_list = glob.glob(folder_path+'*')
    # Calculate len
    self.data_len = len(self.image_list)

  def __getitem__(self, index):
    # Get image name from the pandas df
    single_image_path = self.image_list[index]
    # Open image
    im_as_im = Image.open(single_image_path) # cv2.imread()

    # Do some operations on image
    # Convert to numpy, dim = 28x28
    im_as_np = np.asarray(im_as_im)/255
    # Add channel dimension, dim = 1x28x28
    # Note: You do not need to do this if you are reading RGB images
    # or i there is already channel dimension
    im_as_np = np.expand_dims(im_as_np, 0)
    # Some perprocessing operations on numpy array
          # ...
    # Transform image to tensor, change data type
    im_as_ten = torch.from_numpy(im_as_np).float()

    # Get label(class) of the image based on the file name
    class_indicator_location = single_image_path.rfind('_c')
    label = int(single_image_path[class_indicator_location+2:class_indicator_location+3])
    return (im_as_ten, label) # data pair

    def __len__(self):
      return self.data_len

# %%
custom_mnist_from_file = CustomDatasetFromFile(os.getcwd()+'/mnist_with_class/')

# %%
train_data = torch.Tensor(49,28,28)
train_label = torch.LongTensor(49)
for idx in range(1,49):
  tt1, tt2 = custom_mnist_from_file[idx]
  train_data[idx] = tt1
  train_label[idx] = tt2
torch.save(train_data, 'train_classify_data.pt')
torch.save(train_label, 'train_classify_label.pt')

# %%
print(train_data.shape, train_label.shape)
plt.imshow(train_data[10], cmap = 'gray')
print('The label of the image is:', train_label[10])
# print(train_label[10])
# Out:
# torch.Size([49, 28, 28]) torch.Size([49])
# The label of the image is: tensor(1)

# %%
plt.rcParams['figure.figsize'] = [20, 5]
for idx in range(1,12):
  plt.subplot(1,12,idx).imshow(train_data[idx],cmap='gray'),plt.xticks([]),plt.yticks([]),plt.title(train_label[idx].numpy())

# %%
plt.rcParams['figure.figsize'] = [20, 5]
for idx in range(1,12):
  plt.subplot(1,12,idx).imshow(train_data[idx+12],cmap='gray'),plt.xticks([]),plt.yticks([]),plt.title(train_label[idx+12].numpy())

# %%
plt.rcParams['figure.figsize'] = [20, 5]
for idx in range(1,12):
  plt.subplot(1,12,idx).imshow(train_data[idx+24],cmap='gray'),plt.xticks([]),plt.yticks([]),plt.title(train_label[idx+24].numpy())

# %%
plt.rcParams['figure.figsize'] = [20, 5]
for idx in range(1,12):
  plt.subplot(1,12,idx).imshow(train_data[idx+36],cmap='gray'),plt.xticks([]),plt.yticks([]),plt.title(train_label[idx+36].numpy())

# %% [markdown]
# Load các dữ liệu đã lưu

# %%
data_folder = os.getcwd()
''' x_train = np.load(data_folder+'/x_trainPH2_128.npy')
y_train = np.load(data_folder+'/y_trainPH2_128.npy')

x_test = np.load(data_folder+'/x_testPH2_128.npy')
y_test = np.load(data_folder+'/y_testPH2_128.npy')

x_train = torch.tensor(x_train)
y_train = torch.tensor(y_train)
x_train = x_train.permute(0, 3, 1, 2).float()
y_train = y_train.permute(0, 3, 1, 2).float()
x_test = torch.tensor(x_test).float()
y_test = torch.tensor(y_test).float()
x_test = x_test.permute(0, 3, 1, 2)
y_test = y_test.permute(0, 3, 1, 2)
train_ds = (x_train, y_train) # muon thuc hien augmentation thi nen dua np.load vao class Dataset
val_ds = (x_test, y_test)

BATCH_SIZE = 4
NUM_WORKERS = 2
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
PIN_MEMORY = True
train_loader_1 = DataLoader(
    train_ds,
    batch_size = BATCH_SIZE,
    num_workers = NUM_WORKERS,
    pin_memory = PIN_MEMORY,
    shuffle=True,
)
val_loader_1 = DataLoader(
    val_ds,
    batch_size=BATCH_SIZE,
    num_workers = NUM_WORKERS,
    pin_memory = PIN_MEMORY,
    shuffle=False
)'''
# Out:
# " x_train = np.load(data_folder+'/x_trainPH2_128.npy')\ny_train = np.load(data_folder+'/y_trainPH2_128.npy')\n\nx_test = np.load(data_folder+'/x_testPH2_128.npy')\ny_test = np.load(data_folder+'/y_testPH2_128.npy')\n\nx_train = torch.tensor(x_train)\ny_train = torch.tensor(y_train)\nx_train = x_train.permute(0, 3, 1, 2).float()\ny_train = y_train.permute(0, 3, 1, 2).float()\nx_test = torch.tensor(x_test).float()\ny_test = torch.tensor(y_test).float()\nx_test = x_test.permute(0, 3, 1, 2)\ny_test = y_test.permute(0, 3, 1, 2)\ntrain_ds = (x_train, y_train) # muon thuc hien augmentation thi nen dua np.load vao class Dataset\nval_ds = (x_test, y_test)\n\nBATCH_SIZE = 4\nNUM_WORKERS = 2\nIMAGE_HEIGHT = 128\nIMAGE_WIDTH = 128\nPIN_MEMORY = True\ntrain_loader_1 = DataLoader(\n    train_ds,\n    batch_size = BATCH_SIZE,\n    num_workers = NUM_WORKERS,\n    pin_memory = PIN_MEMORY,\n    shuffle=True,\n)\nval_loader_1 = DataLoader(\n    val_ds,\n    batch_size=BATCH_SIZE,\n    num_workers = NUM_WORKERS,\n    pin_memory = PIN_MEMORY,\n    shuffle=False\n)"

# %%
from torch.utils.data.dataset import Dataset
class Data_from_npy(Dataset):
  def __init__(self, image_path, mask_path, transform = None):
    self.image_path = image_path
    self.mask_path = mask_path
    self.image = np.load(image_path)
    self.mask = np.load(mask_path)
    self.transform = transform

  def __len__(self):
    return self.image.shape[0]

  def __getitem__(self, index):
    image = self.image[index]
    mask = self.mask[index]

    if self.transform is not None:
      augmentations = self.transform(image = image, mask = mask)
      image = augmentations['image']
      mask = augmentations['mask']
    return image, mask

# %%
### read from the .npy file we've saved above

image_path = os.getcwd() + '/sample_skin_data.npy'
mask_path = os.getcwd() + '/sample_skin_label.npy'
train_data = Data_from_npy(image_path, mask_path, transform=None)

# %%
numshow=10
img_set = np.random.randint(len(train_data),size =numshow)
plt.figure(1)
plt.rcParams['figure.figsize'] = [20, 5]
for i,j in enumerate(img_set):
  X, y = train_data[j]
  plt.subplot(1,numshow,i+1).imshow(X.astype(np.int32)),plt.xticks([]),plt.yticks([]),plt.title(i)

plt.figure(2)
plt.rcParams['figure.figsize'] = [20, 5]
for i,j in enumerate(img_set):
  X, y = train_data[j]
  plt.subplot(1,numshow,i+1).imshow(y,cmap='gray'),plt.xticks([]),plt.yticks([]),plt.title(i)

# %%
plt.figure(3)
plt.rcParams['figure.figsize'] = [20, 5]
for i,j in enumerate(img_set):
  X, y = train_data[j]
  plt.subplot(1,numshow,i+1).imshow(X.astype(np.int32)),plt.xticks([]),plt.yticks([]),plt.title(i)
  plt.contour(y,[0],colors='g',linewidth=1.5)
# Out:
# <ipython-input-65-3ab263846152>:6: UserWarning: No contour levels were found within the data range.
#   plt.contour(y,[0],colors='g',linewidth=1.5)
# <ipython-input-65-3ab263846152>:6: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(y,[0],colors='g',linewidth=1.5)
